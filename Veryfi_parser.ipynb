# %%
import json
import pandas as pd
from pandas.io.json import json_normalize
import glob, os

# %%
#filename = "veryfi_s11.json"
#f = open(filename,) 
#data = json.load(f) 
#data['filename']=filename

dd = []
for file in glob.glob("*.json"):
    filename = file
    #print(filename)
    f = open(filename,) 
    dt = json.load(f) 
    dt['filename']=filename
    dd.append(dt)

# %%
new = pd.DataFrame.from_dict(dd)

# %%
new
# Out:
#    abn_number      account_number bill_to_address bill_to_name  \
# 0                          G90737
# 1                          521389
# 2                            4011
# 3
# 4              601777352601862122
# 5
# 6
# 7                            4011
# 8                          052965
# 9
# 10
# 11
# 12               6274219641580677
# 13                          40115
# 14             601777352528729701
# 15
# 16                         815759
# 17
# 18                         060881
# 19
# 20
# 21                            266
# 22
# 23
# 24             601777352528729761
# 25                                                   KRISTIN K
# 26
# 27                           4011
# 28
# 29                         910327
# 30
# 31
# 32                         863957
# 33                         954245
# 34
# 35
# 36
# 37
# 38                           4011
# 39                         089201
# 40
# 41
# 42
# 43
# 44             601777352601862122
# ...

# %%
#line_items = pd.DataFrame(new["line_items"])

# %%
#type(line_items["line_items"])
# Out:
# pandas.core.series.Series

# %%
#line_items['line_items'].apply(pd.Series)

# %%
#item=pd.DataFrame(line_items.line_items.tolist(), index= line_items.index)

# %%
#item["filename"] = new["filename"]

# %%
#item

# %%
#column_names = ['filename','item_num','description','quantity','sku','price','total','date','id']
#final = pd.DataFrame(columns = column_names)
#final

# %%
#item1 = item1[['desc','descClean','lineTotal','qty','productCode','unit']]

# %%
#dtt = pd.DataFrame(d.items())
#dtt = dtt[:1].transpose()

# %%
#dtt

# %%
#final = final.append(dtt)

# %%
#final

# %%
#col = 0
#row_index = 0
#f_index = 0

#if item[col][row_index] != None:
#    d = item[col][row_index]
#    d['item_num']=1   
#d['filename'] = item['filename'][row_index]
#dtt = pd.DataFrame(d.items())
#dtt = dtt.transpose()
#final = final.append(dtt)
#item1 = item1.transpose()*/

# %%
#final

# %%
#item1 = pd.DataFrame(d.items())

# %%
#item1.transpose()

# %%
#item1 = item1[['desc','descClean','lineTotal','qty','productCode','unit']]

# %%
#d['description']

# %%
column_names = ['filename','item_num','description','quantity','sku','price','total','date','id']
final = pd.DataFrame(columns = column_names)
final
# Out:
# Empty DataFrame
# Columns: [filename, item_num, description, quantity, sku, price, total, date, id]
# Index: []

# %%
for row_index in item.index:
    it = 1
    for col in range(0,14):
        if item[col][row_index] != None:
            d = item[col][row_index]
            d['item_num']=str(it)
            it=it+1
        #print(type(d),item[col][row_index])
        d['filename'] = item['filename'][row_index]
        dtt = pd.DataFrame(d.items())
        dtt = dtt.transpose()
        final = final.append(dtt)
#item1 = item1.transpose()

# %%
final
# Out:
#        0            1         2         3      4      5         6          7  \
# 0   date  description  discount        id  order  price  quantity  reference
# 1          REGULAR\nL         0  25125584      0  1.029    19.443
# 0   date  description  discount        id  order  price  quantity  reference
# 1          REGULAR\nL         0  25125584      0  1.029    19.443
# 0   date  description  discount        id  order  price  quantity  reference
# ..   ...          ...       ...       ...    ...    ...       ...        ...
# 1             EREG\nL         0  25125613      0  1.019    29.504
# 0   date  description  discount        id  order  price  quantity  reference
# 1             EREG\nL         0  25125613      0  1.019    29.504
# 0   date  description  discount        id  order  price  quantity  reference
# 1             EREG\nL         0  25125613      0  1.019    29.504
#
#       8    9  ...               15 date description filename   id item_num  \
# ...

# %%
final.drop(['filename','item_num','description','quantity','sku','price','total','date','id'], axis=1, inplace=True)

# %%
final
# Out:
#       0            1         2         3      4      5         6          7   \
# 0   date  description  discount        id  order  price  quantity  reference
# 1          REGULAR\nL         0  25125584      0  1.029    19.443
# 0   date  description  discount        id  order  price  quantity  reference
# 1          REGULAR\nL         0  25125584      0  1.029    19.443
# 0   date  description  discount        id  order  price  quantity  reference
# ..   ...          ...       ...       ...    ...    ...       ...        ...
# 1             EREG\nL         0  25125613      0  1.019    29.504
# 0   date  description  discount        id  order  price  quantity  reference
# 1             EREG\nL         0  25125613      0  1.019    29.504
# 0   date  description  discount        id  order  price  quantity  reference
# 1             EREG\nL         0  25125613      0  1.019    29.504
#
#      8    9         10     11    12               13        14  \
# ...

# %%
new_header = final.iloc[0] #grab the first row for the header
final = final[1:] #take the data less the header row
final.columns = new_header #set the header row as the df header
#df_n = df_n[3:]
final
# Out:
# 0   date  description  discount        id  order  price  quantity  reference  \
# 1          REGULAR\nL         0  25125584      0  1.029    19.443
# 0   date  description  discount        id  order  price  quantity  reference
# 1          REGULAR\nL         0  25125584      0  1.029    19.443
# 0   date  description  discount        id  order  price  quantity  reference
# 1          REGULAR\nL         0  25125584      0  1.029    19.443
# ..   ...          ...       ...       ...    ...    ...       ...        ...
# 1             EREG\nL         0  25125613      0  1.019    29.504
# 0   date  description  discount        id  order  price  quantity  reference
# 1             EREG\nL         0  25125613      0  1.019    29.504
# 0   date  description  discount        id  order  price  quantity  reference
# 1             EREG\nL         0  25125613      0  1.019    29.504
#
# 0   sku  tax  tax_rate  total  type  unit_of_measure  item_num  \
# ...

# %%
final["index1"]=final.index
# Out:
# <ipython-input-219-0071f459fd66>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final["index1"]=final.index

# %%
final
# Out:
# 0   date  description  discount        id  order  price  quantity  reference  \
# 1          REGULAR\nL         0  25125584      0  1.029    19.443
# 0   date  description  discount        id  order  price  quantity  reference
# 1          REGULAR\nL         0  25125584      0  1.029    19.443
# 0   date  description  discount        id  order  price  quantity  reference
# 1          REGULAR\nL         0  25125584      0  1.029    19.443
# ..   ...          ...       ...       ...    ...    ...       ...        ...
# 1             EREG\nL         0  25125613      0  1.019    29.504
# 0   date  description  discount        id  order  price  quantity  reference
# 1             EREG\nL         0  25125613      0  1.019    29.504
# 0   date  description  discount        id  order  price  quantity  reference
# 1             EREG\nL         0  25125613      0  1.019    29.504
#
# 0   sku  tax  tax_rate  total  type  unit_of_measure  item_num  \
# ...

# %%
final.reset_index(inplace = True)

# %%
final
# Out:
# 0     index  date  description  discount        id  order  price  quantity  \
# 0         1         REGULAR\nL         0  25125584      0  1.029    19.443
# 1         0  date  description  discount        id  order  price  quantity
# 2         1         REGULAR\nL         0  25125584      0  1.029    19.443
# 3         0  date  description  discount        id  order  price  quantity
# 4         1         REGULAR\nL         0  25125584      0  1.029    19.443
# ...     ...   ...          ...       ...       ...    ...    ...       ...
# 1394      1            EREG\nL         0  25125613      0  1.019    29.504
# 1395      0  date  description  discount        id  order  price  quantity
# 1396      1            EREG\nL         0  25125613      0  1.019    29.504
# 1397      0  date  description  discount        id  order  price  quantity
# 1398      1            EREG\nL         0  25125613      0  1.019    29.504
#
# ...

# %%
final = final[final['index1']==1]

# %%
final
# Out:
# 0     index date description discount        id order  price quantity  \
# 0         1       REGULAR\nL        0  25125584     0  1.029   19.443
# 2         1       REGULAR\nL        0  25125584     0  1.029   19.443
# 4         1       REGULAR\nL        0  25125584     0  1.029   19.443
# 6         1       REGULAR\nL        0  25125584     0  1.029   19.443
# 8         1       REGULAR\nL        0  25125584     0  1.029   19.443
# ...     ...  ...         ...      ...       ...   ...    ...      ...
# 1390      1          EREG\nL        0  25125613     0  1.019   29.504
# 1392      1          EREG\nL        0  25125613     0  1.019   29.504
# 1394      1          EREG\nL        0  25125613     0  1.019   29.504
# 1396      1          EREG\nL        0  25125613     0  1.019   29.504
# 1398      1          EREG\nL        0  25125613     0  1.019   29.504
#
# 0    reference sku tax tax_rate  total  type unit_of_measure item_num  \
# ...

# %%
final.reset_index(inplace = True)

# %%
final
# Out:
# 0    level_0  index date description discount        id order  price quantity  \
# 0          0      1       REGULAR\nL        0  25125584     0  1.029   19.443
# 1          2      1       REGULAR\nL        0  25125584     0  1.029   19.443
# 2          4      1       REGULAR\nL        0  25125584     0  1.029   19.443
# 3          6      1       REGULAR\nL        0  25125584     0  1.029   19.443
# 4          8      1       REGULAR\nL        0  25125584     0  1.029   19.443
# ..       ...    ...  ...         ...      ...       ...   ...    ...      ...
# 695     1390      1          EREG\nL        0  25125613     0  1.019   29.504
# 696     1392      1          EREG\nL        0  25125613     0  1.019   29.504
# 697     1394      1          EREG\nL        0  25125613     0  1.019   29.504
# 698     1396      1          EREG\nL        0  25125613     0  1.019   29.504
# 699     1398      1          EREG\nL        0  25125613     0  1.019   29.504
#
# ...

# %%
final.drop(['level_0','index','index1'], axis=1, inplace=True)
# Out:
# /Users/priyankamukherjee/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
final
# Out:
# 0   date description discount        id order  price quantity reference sku  \
# 0         REGULAR\nL        0  25125584     0  1.029   19.443
# 1         REGULAR\nL        0  25125584     0  1.029   19.443
# 2         REGULAR\nL        0  25125584     0  1.029   19.443
# 3         REGULAR\nL        0  25125584     0  1.029   19.443
# 4         REGULAR\nL        0  25125584     0  1.029   19.443
# ..   ...         ...      ...       ...   ...    ...      ...       ...  ..
# 695          EREG\nL        0  25125613     0  1.019   29.504
# 696          EREG\nL        0  25125613     0  1.019   29.504
# 697          EREG\nL        0  25125613     0  1.019   29.504
# 698          EREG\nL        0  25125613     0  1.019   29.504
# 699          EREG\nL        0  25125613     0  1.019   29.504
#
# 0   tax tax_rate  total  type unit_of_measure item_num         filename
# 0     0        0  20.01  fuel          LITRES        1  veryfi_s61.json
# ...

# %%
final_merged = pd.merge(final, new, on='filename', how='outer')

# %%
list(final_merged)
# Out:
# ['date_x',
#  'description',
#  'discount_x',
#  'id_x',
#  'order',
#  'price',
#  'quantity',
#  'reference',
#  'sku',
#  'tax_x',
#  'tax_rate',
#  'total_x',
#  'type',
#  'unit_of_measure',
#  'item_num',
#  'filename',
#  'abn_number',
#  'account_number',
#  'bill_to_address',
#  'bill_to_name',
#  'bill_to_vat_number',
#  'card_number',
#  'cashback',
#  'category',
#  'currency_code',
#  'date_y',
#  'discount_y',
#  'due_date',
#  'external_id',
#  'id_y',
#  'img_file_name',
#  'img_thumbnail_url',
#  'img_url',
#  'invoice_number',
#  'line_items',
#  'ocr_text',
#  'payment_display_name',
#  'payment_terms',
#  'payment_type',
#  'phone_number',
#  'purchase_order_number',
#  'reference_number',
#  'rounding',
#  'service_end_date',
#  'service_start_date',
#  'shipping',
#  'subtotal',
#  'tax_y',
#  'tax_lines',
#  'tip',
#  'total_y',
#  'tracking_number',
#  'vat_number',
#  'vendor',
#  'vendor_account_number',
#  'vendor_bank_name',
#  'vendor_bank_number',
# ...

# %%
final_merged = final_merged[['date_x',
 'description',
 'discount_x',
 'id_x',
 'order',
 'price',
 'quantity',
 'sku',
 'tax_x',
 'tax_rate',
 'total_x',
 'type',
 'unit_of_measure',
 'item_num',
 'filename',
 'card_number',
 'cashback',
 'category',
 'currency_code',
 'date_y',
 'discount_y',
 'external_id',
 'id_y',
 'invoice_number',
 'payment_display_name',
 'payment_type',
 'shipping',
 'subtotal',
 'tax_y',
 'tip',
 'total_y',
'vendor'
 ]]

# %%
final_merged
# Out:
#     date_x description discount_x      id_x order  price quantity sku tax_x  \
# 0           REGULAR\nL          0  25125584     0  1.029   19.443         0
# 1           REGULAR\nL          0  25125584     0  1.029   19.443         0
# 2           REGULAR\nL          0  25125584     0  1.029   19.443         0
# 3           REGULAR\nL          0  25125584     0  1.029   19.443         0
# 4           REGULAR\nL          0  25125584     0  1.029   19.443         0
# ..     ...         ...        ...       ...   ...    ...      ...  ..   ...
# 695            EREG\nL          0  25125613     0  1.019   29.504         0
# 696            EREG\nL          0  25125613     0  1.019   29.504         0
# 697            EREG\nL          0  25125613     0  1.019   29.504         0
# 698            EREG\nL          0  25125613     0  1.019   29.504         0
# 699            EREG\nL          0  25125613     0  1.019   29.504         0
#
# ...

# %%
s = final_merged['vendor']

# %%
type(final_merged['vendor'].apply(pd.Series))
# Out:
# pandas.core.frame.DataFrame

# %%
vendor_df = final_merged['vendor'].apply(pd.Series)

# %%
vendor_df.head()
# Out:
#                                              address email fax_number  \
# 0  1 Paisley Crt (Brock St & Consumers Dr), Whitb...
# 1  1 Paisley Crt (Brock St & Consumers Dr), Whitb...
# 2  1 Paisley Crt (Brock St & Consumers Dr), Whitb...
# 3  1 Paisley Crt (Brock St & Consumers Dr), Whitb...
# 4  1 Paisley Crt (Brock St & Consumers Dr), Whitb...
#
#            name phone_number      raw_name  \
# 0  Petro-Canada               Petro-Canada
# 1  Petro-Canada               Petro-Canada
# 2  Petro-Canada               Petro-Canada
# 3  Petro-Canada               Petro-Canada
# 4  Petro-Canada               Petro-Canada
#
#                                      vendor_logo  vendor_type web
# 0  https://cdn.veryfi.com/logos/us/900637360.png  gas station
# 1  https://cdn.veryfi.com/logos/us/900637360.png  gas station
# 2  https://cdn.veryfi.com/logos/us/900637360.png  gas station
# 3  https://cdn.veryfi.com/logos/us/900637360.png  gas station
# ...

# %%
final_merged = pd.merge(final_merged, vendor_df, left_index=True, right_index=True, how='outer')

# %%
final_merged.drop(['vendor','address','email','fax_number','phone_number','vendor_logo','web'], axis=1, inplace=True)

# %%
final_merged.to_csv('Veryfi.csv')
